# %% [markdown]
# Purpose: Aggregating NCES Demographic data
#
# The data was taken from IES NCES Education Demographic and Geographic estimates website (https://nces.ed.gov/programs/edge/tableviewer/acsProfile/2022) for each  population group. The total of 15 text files were converted into .xlsx. The data was taken from 2018-2022 (latest).
#
# - Total Populations
# - Total Children
# - Relevant Children
# - Total Parents
# - Parents of Relevant Children
#
# Each population group has 3 types of data:
# - Social
# - Demographic
# - Economic
#
# Each of these type of data contains many columns regarding the details of the population which contains:
# - Estimate
# - Margin of error
# - Percent estimate
# - Percent margin of error
#
# Each of the columns has a code name, which can be referenced from ACS-ED_2018-2022_RecordLayouts file in each folder. Because of the issue with having the same code name for columns of similar population (Total Children vs Relevant Children, and Total Parents vs Parents of Relevant Children), the code name for columns of Total Children and Total Parents of Relevant Children were added a "T" into the beginning of the code name (example: CDP02_2est becomes TCDP02_2est for Married Couple Household of Total Children file while CDP02_2est is still Married Couple Household for Relevant Children file).
#
# Only the Estimate and Percent Estimate columns were kept after merging. There is one Finance_main_data excel file containing both types of columns (1556 cols, 13399 rows (districts))for all files and 2 excel files containing Estimate (1320 cols, 13399 districts) and Percent Estimate (1126 cols, 13399 districts ) separately.

# %%
# Converting from txt to xlsx

import os
import pandas as pd

# Get the current working directory (where the notebook is located)
current_dir = os.path.abspath("")  # This will get the current working directory

# Function to convert text file to Excel with "|" delimiter
def txt_to_excel(txt_file, excel_file):
    # Read the text file into a DataFrame with "|" delimiter and low_memory=False
    df = pd.read_csv(txt_file, delimiter='|', header=None, low_memory=False)
    # Write the DataFrame to an Excel file
    df.to_excel(excel_file, index=False, header=False)

# Iterate over the folders and files in the current directory
for item_name in os.listdir(current_dir):
    item_path = os.path.join(current_dir, item_name)
    
    # Check if it's a directory and not the .ipynb_checkpoints
    if os.path.isdir(item_path) and item_name != '.ipynb_checkpoints':
        for file_name in os.listdir(item_path):
            file_path = os.path.join(item_path, file_name)
            
            # Check if it's a text file
            if file_name.endswith('.txt'):
                # Define the Excel file path within the same directory as the text file
                excel_file_name = f"{item_name}.xlsx"
                excel_file_path = os.path.join(item_path, excel_file_name)
                
                # Convert the text file to Excel
                txt_to_excel(file_path, excel_file_path)
                print(f"Converted {file_path} to {excel_file_path}\n")

print("Conversion completed.")
# Out:
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Parent of Relevant Children Demographic 2018-2022\PDP05_205_USSchoolDistrictAll_614125158923.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Parent of Relevant Children Demographic 2018-2022\Parent of Relevant Children Demographic 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Parent of Relevant Children Economic 2018-2022\PDP03_205_USSchoolDistrictAll_614125110266.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Parent of Relevant Children Economic 2018-2022\Parent of Relevant Children Economic 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Parent of Relevant Children Social 2018-2022\PDP02_205_USSchoolDistrictAll_614124945108.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Parent of Relevant Children Social 2018-2022\Parent of Relevant Children Social 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Relevant Children Demographic 2018-2022\CDP05_105_USSchoolDistrictAll_614124421732.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Relevant Children Demographic 2018-2022\Relevant Children Demographic 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Relevant Children Economic 2018-2022\CDP03_105_USSchoolDistrictAll_614124326841.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Relevant Children Economic 2018-2022\Relevant Children Economic 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Relevant Children Social 2018-2022\CDP02_105_USSchoolDistrictAll_614124216231.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Relevant Children Social 2018-2022\Relevant Children Social 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Children Demographic 2018-2022\CDP05_101_USSchoolDistrictAll_61821414979.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Children Demographic 2018-2022\Total Children Demographic 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Children Economic 2018-2022\CDP03_101_USSchoolDistrictAll_614123846371.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Children Economic 2018-2022\Total Children Economic 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Children Social 2018-2022\CDP02_101_USSchoolDistrictAll_614123640198.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Children Social 2018-2022\Total Children Social 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Parents Demographic 2018-2022\PDP05_201_USSchoolDistrictAll_614124833858.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Parents Demographic 2018-2022\Total Parents Demographic 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Parents Economic 2018-2022\PDP03_201_USSchoolDistrictAll_6182149237.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Parents Economic 2018-2022\Total Parents Economic 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Parents Social 2018-2022\PDP02_201_USSchoolDistrictAll_614124524951.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Parents Social 2018-2022\Total Parents Social 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Population Demographic 2018-2022\DP05_001_USSchoolDistrictAll_619239838.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Population Demographic 2018-2022\Total Population Demographic 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Population Economic 2018-2022\DP03_001_USSchoolDistrictAll_614114336982.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Population Economic 2018-2022\Total Population Economic 2018-2022.xlsx
#
# Converted C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Population Social 2018-2022\DP02_001_USSchoolDistrictAll_614115014797.txt to C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Total Population Social 2018-2022\Total Population Social 2018-2022.xlsx
#
# Conversion completed.

# %%
# Get list of relevant columns from all excel files, keeping only keys, estimate and percent
# Excludes margin of error and percent margin of error columns
# Renaming the files starting with "Total children ..." and "Total Parents ..." because they have the same column names as those of some other files

import os
import re
import pandas as pd

# Get the current working directory (where the notebook is located)
current_dir = os.path.abspath("")

# Initialize an empty set to store unique column names
unique_columns = set()

# Columns to ensure are always included
always_included_columns = ['GeoId', 'Geography', 'LEAID', 'Year']
dont_rename = ['GeoId', 'Geography', 'LEAID', 'Year', 'Iteration']

# Function to add columns to unique_columns set
def add_columns_to_set(columns):
    for col in columns:
        unique_columns.add(col)

# Function to remove columns ending with "moe" or "pctmoe" and excluding 'Iteration'
def filter_columns(columns):
    filtered_columns = set()
    columns_to_remove = {'moe', 'pctmoe'}
    for col in columns:
        if not any(col.lower().endswith(suffix) for suffix in columns_to_remove) and col.lower() != 'iteration':
            filtered_columns.add(col)
    return filtered_columns

# Function to fix columns for files in "Total Children ..." and "Total Parents ..." folders
def fix_and_rename_columns(df, folder_name, excel_file_path):
    if folder_name.startswith("Total Children") or folder_name.startswith("Total Parents"):
        # Remove all existing "T" prefixes
        df.columns = [col.lstrip('T') if col not in dont_rename else col for col in df.columns]
        # Add "T" prefix back where necessary
        df.rename(columns={col: f'T{col}' for col in df.columns if col not in dont_rename}, inplace=True)
        print(f"Fixing and renaming columns in: {folder_name}")
        # Save the updated DataFrame back to the Excel file
        df.to_excel(excel_file_path, index=False)
    return df

# Add always included columns to the unique_columns set
add_columns_to_set(always_included_columns)

# Iterate over each folder in the current directory
for item_name in os.listdir(current_dir):
    item_path = os.path.join(current_dir, item_name)
    
    if os.path.isdir(item_path):
        # Construct the expected Excel file path
        excel_file_path = os.path.join(item_path, f"{item_name}.xlsx")
        
        # Check if the Excel file exists
        if os.path.exists(excel_file_path):
            print(f"Processing Excel file: {item_name}")
            
            # Read the data from the Excel file
            df = pd.read_excel(excel_file_path)
            
            # Fix and rename columns if in "Total Children ..." or "Total Parents ..." folders
            df = fix_and_rename_columns(df, item_name, excel_file_path)
            
            # Print the number of columns taken from this file before filtering
            print(f"Number of columns taken before filtering: {len(df.columns)}")

            # Filter columns based on unique_column_names
            filtered_cols = filter_columns(df.columns)
            print(f"Number of columns taken after filtering: {len(filtered_cols)}\n")

            # Add columns to unique_columns set
            add_columns_to_set(filtered_cols)

# Filter columns to remove those ending with "moe" or "pctmoe"
filtered_columns = filter_columns(unique_columns)

# Function to sort columns in the desired order
def sort_columns(cols):
    def custom_sort_key(col):
        match = re.match(r'(CDP|DP|PDP|TCDP|TPDP)(\d+)_(\d+)(est|pct)', col)
        if match:
            main_prefix, main_num, sub_num, suffix = match.groups()
            return (main_prefix, int(main_num), int(sub_num), suffix)
        return ('', float('inf'))

    return sorted(cols, key=custom_sort_key)

unique_column_names = sort_columns(filtered_columns)

# Ensure always included columns are at the beginning of the list
for col in reversed(always_included_columns):
    if col in unique_column_names:
        unique_column_names.remove(col)
    unique_column_names.insert(0, col)

# Print the count of unique column names
print(f"\nNumber of unique column names across all Excel files in current directory: {len(unique_column_names)}")

# Print or use the unique column names
print("\nUnique column names across all Excel files in current directory:")
for col in unique_column_names:
    print(col)
# Out:
# Processing Excel file: Parent of Relevant Children Demographic 2018-2022
# Number of columns taken before filtering: 277
# Number of columns taken after filtering: 140
#
# Processing Excel file: Parent of Relevant Children Economic 2018-2022
# Number of columns taken before filtering: 261
# Number of columns taken after filtering: 132
#
# Processing Excel file: Parent of Relevant Children Social 2018-2022
# Number of columns taken before filtering: 435
# Number of columns taken after filtering: 219
#
# Processing Excel file: Relevant Children Demographic 2018-2022
# Number of columns taken before filtering: 269
# Number of columns taken after filtering: 136
#
# Processing Excel file: Relevant Children Economic 2018-2022
# Number of columns taken before filtering: 207
# Number of columns taken after filtering: 105
#
# Processing Excel file: Relevant Children Social 2018-2022
# Number of columns taken before filtering: 353
# Number of columns taken after filtering: 178
#
# Processing Excel file: Total Children Demographic 2018-2022
# Fixing and renaming columns in: Total Children Demographic 2018-2022
# Number of columns taken before filtering: 269
# Number of columns taken after filtering: 136
#
# Processing Excel file: Total Children Economic 2018-2022
# Fixing and renaming columns in: Total Children Economic 2018-2022
# Number of columns taken before filtering: 207
# Number of columns taken after filtering: 105
#
# Processing Excel file: Total Children Social 2018-2022
# Fixing and renaming columns in: Total Children Social 2018-2022
# Number of columns taken before filtering: 353
# Number of columns taken after filtering: 178
#
# Processing Excel file: Total Parents Demographic 2018-2022
# Fixing and renaming columns in: Total Parents Demographic 2018-2022
# Number of columns taken before filtering: 277
# Number of columns taken after filtering: 140
#
# Processing Excel file: Total Parents Economic 2018-2022
# Fixing and renaming columns in: Total Parents Economic 2018-2022
# Number of columns taken before filtering: 261
# Number of columns taken after filtering: 132
#
# Processing Excel file: Total Parents Social 2018-2022
# Fixing and renaming columns in: Total Parents Social 2018-2022
# Number of columns taken before filtering: 435
# Number of columns taken after filtering: 219
#
# Processing Excel file: Total Population Demographic 2018-2022
# Number of columns taken before filtering: 345
# Number of columns taken after filtering: 174
#
# Processing Excel file: Total Population Economic 2018-2022
# Number of columns taken before filtering: 443
# Number of columns taken after filtering: 223
#
# Processing Excel file: Total Population Social 2018-2022
# Number of columns taken before filtering: 559
# Number of columns taken after filtering: 281
#
#
# Number of unique column names across all Excel files in current directory: 2442
#
# Unique column names across all Excel files in current directory:
# GeoId
# Geography
# LEAID
# Year
# CDP02_1est
# CDP02_2est
# CDP02_2pct
# CDP02_3est
# CDP02_3pct
# CDP02_4est
# CDP02_4pct
# CDP02_5est
# CDP02_5pct
# CDP02_6est
# CDP02_6pct
# CDP02_7est
# CDP02_7pct
# CDP02_8est
# CDP02_9est
# CDP02_10est
# CDP02_11est
# CDP02_11pct
# CDP02_12est
# CDP02_12pct
# CDP02_13est
# CDP02_13pct
# CDP02_14est
# CDP02_14pct
# CDP02_15est
# CDP02_15pct
# CDP02_16est
# CDP02_17est
# CDP02_17pct
# CDP02_18est
# CDP02_19est
# CDP02_19pct
# CDP02_20est
# CDP02_21est
# CDP02_21pct
# CDP02_22est
# CDP02_22pct
# CDP02_23est
# CDP02_23pct
# CDP02_24est
# CDP02_24pct
# CDP02_25est
# CDP02_25pct
# CDP02_26est
# CDP02_26pct
# CDP02_27est
# CDP02_27pct
# CDP02_28est
# CDP02_28pct
# CDP02_29est
# CDP02_30est
# CDP02_30pct
# CDP02_31est
# CDP02_31pct
# CDP02_32est
# CDP02_32pct
# CDP02_33est
# CDP02_33pct
# CDP02_34est
# CDP02_34pct
# CDP02_35est
# CDP02_35pct
# CDP02_36est
# CDP02_37est
# CDP02_37pct
# CDP02_38est
# CDP02_38pct
# CDP02_39est
# CDP02_40est
# CDP02_41est
# CDP02_41pct
# CDP02_42est
# CDP02_42pct
# CDP02_43est
# CDP02_44est
# CDP02_44pct
# CDP02_45est
# CDP02_45pct
# CDP02_46est
# CDP02_47est
# CDP02_47pct
# CDP02_48est
# CDP02_48pct
# CDP02_49est
# CDP02_49pct
# CDP02_50est
# CDP02_50pct
# CDP02_51est
# CDP02_51pct
# CDP02_52est
# CDP02_52pct
# CDP02_53est
# CDP02_54est
# CDP02_54pct
# CDP02_55est
# CDP02_55pct
# CDP02_56est
# CDP02_56pct
# CDP02_57est
# CDP02_57pct
# CDP02_58est
# CDP02_58pct
# CDP02_59est
# CDP02_59pct
# CDP02_60est
# CDP02_60pct
# CDP02_61est
# CDP02_61pct
# CDP02_62est
# CDP02_62pct
# CDP02_63est
# CDP02_63pct
# CDP02_64est
# CDP02_64pct
# CDP02_65est
# CDP02_66est
# CDP02_66pct
# CDP02_67est
# CDP02_67pct
# CDP02_68est
# CDP02_68pct
# CDP02_69est
# CDP02_69pct
# CDP02_70est
# CDP02_70pct
# CDP02_71est
# CDP02_71pct
# CDP02_72est
# CDP02_72pct
# CDP02_73est
# CDP02_73pct
# CDP02_74est
# CDP02_74pct
# CDP02_75est
# CDP02_75pct
# CDP02_76est
# CDP02_76pct
# CDP02_77est
# CDP02_77pct
# CDP02_78est
# CDP02_78pct
# CDP02_79est
# CDP02_79pct
# CDP02_80est
# CDP02_80pct
# CDP02_81est
# CDP02_81pct
# CDP02_82est
# CDP02_82pct
# CDP02_83est
# CDP02_83pct
# CDP02_84est
# CDP02_84pct
# CDP02_85est
# CDP02_85pct
# CDP02_86est
# CDP02_86pct
# CDP02_87est
# CDP02_87pct
# CDP02_88est
# CDP02_88pct
# CDP02_89est
# CDP02_89pct
# CDP02_90est
# CDP02_90pct
# CDP02_91est
# CDP02_91pct
# CDP02_92est
# CDP02_92pct
# CDP02_93est
# CDP02_94est
# CDP02_94pct
# CDP02_95est
# CDP02_95pct
# CDP03_1est
# CDP03_2est
# CDP03_2pct
# CDP03_3est
# CDP03_4est
# CDP03_4pct
# CDP03_5est
# CDP03_6est
# CDP03_6pct
# CDP03_7est
# CDP03_7pct
# CDP03_8est
# CDP03_8pct
# CDP03_9est
# CDP03_9pct
# CDP03_10est
# CDP03_10pct
# CDP03_11est
# CDP03_11pct
# CDP03_12est
# CDP03_12pct
# CDP03_13est
# CDP03_13pct
# CDP03_14est
# CDP03_14pct
# CDP03_15est
# CDP03_15pct
# CDP03_16est
# CDP03_17est
# CDP03_18est
# CDP03_19est
# CDP03_20est
# CDP03_21est
# CDP03_22est
# CDP03_23est
# CDP03_23pct
# CDP03_24est
# CDP03_25est
# CDP03_25pct
# CDP03_26est
# CDP03_27est
# CDP03_27pct
# CDP03_28est
# CDP03_29est
# CDP03_29pct
# CDP03_30est
# CDP03_31est
# CDP03_31pct
# CDP03_32est
# CDP03_33est
# CDP03_33pct
# CDP03_34est
# CDP03_35est
# CDP03_35pct
# CDP03_36est
# CDP03_36pct
# CDP03_37est
# CDP03_37pct
# CDP03_38est
# CDP03_38pct
# CDP03_39est
# CDP03_39pct
# CDP03_40est
# CDP03_40pct
# CDP03_41est
# CDP03_41pct
# CDP03_42est
# CDP03_42pct
# CDP03_43est
# CDP03_43pct
# CDP03_44est
# CDP03_44pct
# CDP03_45est
# CDP03_46est
# CDP03_47est
# CDP03_48est
# CDP03_48pct
# CDP03_49est
# CDP03_49pct
# CDP03_50est
# CDP03_50pct
# CDP03_51est
# CDP03_51pct
# CDP03_52est
# CDP03_53est
# CDP03_53pct
# CDP03_54pct
# CDP03_55pct
# CDP03_56pct
# CDP03_57pct
# CDP03_58pct
# CDP03_59pct
# CDP03_60pct
# CDP03_61pct
# CDP03_62pct
# CDP03_63pct
# CDP03_64pct
# CDP03_65pct
# CDP03_66pct
# CDP03_67pct
# CDP03_68pct
# CDP05_1est
# CDP05_2est
# CDP05_2pct
# CDP05_3est
# CDP05_3pct
# CDP05_4est
# CDP05_4pct
# CDP05_5est
# CDP05_5pct
# CDP05_6est
# CDP05_6pct
# CDP05_7est
# CDP05_7pct
# CDP05_8est
# CDP05_8pct
# CDP05_9est
# CDP05_9pct
# CDP05_10est
# CDP05_10pct
# CDP05_11est
# CDP05_11pct
# CDP05_12est
# CDP05_12pct
# CDP05_13est
# CDP05_13pct
# CDP05_14est
# CDP05_15est
# CDP05_15pct
# CDP05_16est
# CDP05_16pct
# CDP05_17est
# CDP05_17pct
# CDP05_18est
# CDP05_18pct
# CDP05_19est
# CDP05_19pct
# CDP05_20est
# CDP05_20pct
# CDP05_21est
# CDP05_21pct
# CDP05_22est
# CDP05_22pct
# CDP05_23est
# CDP05_23pct
# CDP05_24est
# CDP05_24pct
# CDP05_25est
# CDP05_25pct
# CDP05_26est
# CDP05_26pct
# CDP05_27est
# CDP05_27pct
# CDP05_28est
# CDP05_28pct
# CDP05_29est
# CDP05_29pct
# CDP05_30est
# CDP05_30pct
# CDP05_31est
# CDP05_31pct
# CDP05_32est
# CDP05_32pct
# CDP05_33est
# CDP05_33pct
# CDP05_34est
# CDP05_34pct
# CDP05_35est
# CDP05_35pct
# CDP05_36est
# CDP05_36pct
# CDP05_37est
# CDP05_37pct
# CDP05_38est
# CDP05_38pct
# CDP05_39est
# CDP05_39pct
# CDP05_40est
# CDP05_40pct
# CDP05_41est
# CDP05_41pct
# CDP05_42est
# CDP05_42pct
# CDP05_43est
# CDP05_43pct
# CDP05_44est
# CDP05_44pct
# CDP05_45est
# CDP05_45pct
# CDP05_46est
# CDP05_47est
# CDP05_47pct
# CDP05_48est
# CDP05_48pct
# CDP05_49est
# CDP05_49pct
# CDP05_50est
# CDP05_50pct
# CDP05_51est
# CDP05_51pct
# CDP05_52est
# CDP05_52pct
# CDP05_53est
# CDP05_54est
# CDP05_54pct
# CDP05_55est
# CDP05_55pct
# CDP05_56est
# CDP05_56pct
# CDP05_57est
# CDP05_57pct
# CDP05_58est
# CDP05_58pct
# CDP05_59est
# CDP05_59pct
# CDP05_60est
# CDP05_60pct
# CDP05_61est
# CDP05_61pct
# CDP05_62est
# CDP05_62pct
# CDP05_63est
# CDP05_63pct
# CDP05_64est
# CDP05_64pct
# CDP05_65est
# CDP05_65pct
# CDP05_66est
# CDP05_66pct
# CDP05_67est
# CDP05_67pct
# CDP05_68est
# CDP05_68pct
# DP02_1est
# DP02_2est
# DP02_2pct
# DP02_3est
# DP02_3pct
# DP02_4est
# DP02_4pct
# DP02_5est
# DP02_5pct
# DP02_6est
# DP02_6pct
# DP02_7est
# DP02_7pct
# DP02_8est
# DP02_8pct
# DP02_9est
# DP02_9pct
# DP02_10est
# DP02_10pct
# DP02_11est
# DP02_11pct
# DP02_12est
# DP02_12pct
# DP02_13est
# DP02_13pct
# DP02_14est
# DP02_14pct
# DP02_15est
# DP02_15pct
# DP02_16est
# DP02_17est
# DP02_18est
# DP02_19est
# DP02_19pct
# DP02_20est
# DP02_20pct
# DP02_21est
# DP02_21pct
# DP02_22est
# DP02_22pct
# DP02_23est
# DP02_23pct
# DP02_24est
# DP02_24pct
# DP02_25est
# DP02_26est
# DP02_26pct
# DP02_27est
# DP02_27pct
# DP02_28est
# DP02_28pct
# DP02_29est
# DP02_29pct
# DP02_30est
# DP02_30pct
# DP02_31est
# DP02_32est
# DP02_32pct
# DP02_33est
# DP02_33pct
# DP02_34est
# DP02_34pct
# DP02_35est
# DP02_35pct
# DP02_36est
# DP02_36pct
# DP02_37est
# DP02_38est
# DP02_38pct
# DP02_39est
# DP02_40est
# DP02_41est
# DP02_42est
# DP02_43est
# DP02_44est
# DP02_45est
# DP02_45pct
# DP02_46est
# DP02_46pct
# DP02_47est
# DP02_47pct
# DP02_48est
# DP02_48pct
# DP02_49est
# DP02_49pct
# DP02_50est
# DP02_51est
# DP02_51pct
# DP02_52est
# DP02_52pct
# DP02_53est
# DP02_54est
# DP02_54pct
# DP02_55est
# DP02_55pct
# DP02_56est
# DP02_56pct
# DP02_57est
# DP02_57pct
# DP02_58est
# DP02_58pct
# DP02_59est
# DP02_60est
# DP02_60pct
# DP02_61est
# DP02_61pct
# DP02_62est
# DP02_62pct
# DP02_63est
# DP02_63pct
# DP02_64est
# DP02_64pct
# DP02_65est
# DP02_65pct
# DP02_66est
# DP02_66pct
# DP02_67est
# DP02_67pct
# DP02_68est
# DP02_68pct
# DP02_69est
# DP02_70est
# DP02_70pct
# DP02_71est
# DP02_72est
# DP02_72pct
# DP02_73est
# DP02_74est
# DP02_74pct
# DP02_75est
# DP02_76est
# DP02_76pct
# DP02_77est
# DP02_78est
# DP02_78pct
# DP02_79est
# DP02_80est
# DP02_80pct
# DP02_81est
# DP02_81pct
# DP02_82est
# DP02_82pct
# DP02_83est
# DP02_83pct
# DP02_84est
# DP02_84pct
# DP02_85est
# DP02_85pct
# DP02_86est
# DP02_86pct
# DP02_87est
# DP02_87pct
# DP02_88est
# DP02_89est
# DP02_89pct
# DP02_90est
# DP02_90pct
# DP02_91est
# DP02_91pct
# DP02_92est
# DP02_92pct
# DP02_93est
# DP02_93pct
# DP02_94est
# DP02_94pct
# DP02_95est
# DP02_96est
# DP02_96pct
# DP02_97est
# DP02_97pct
# DP02_98est
# DP02_99est
# DP02_100est
# DP02_100pct
# DP02_101est
# DP02_101pct
# DP02_102est
# DP02_103est
# DP02_103pct
# DP02_104est
# DP02_104pct
# DP02_105est
# DP02_106est
# DP02_106pct
# DP02_107est
# DP02_107pct
# DP02_108est
# DP02_108pct
# DP02_109est
# DP02_109pct
# DP02_110est
# DP02_110pct
# DP02_111est
# DP02_111pct
# DP02_112est
# DP02_113est
# DP02_113pct
# DP02_114est
# DP02_114pct
# DP02_115est
# DP02_115pct
# DP02_116est
# DP02_116pct
# DP02_117est
# DP02_117pct
# DP02_118est
# DP02_118pct
# DP02_119est
# DP02_119pct
# DP02_120est
# DP02_120pct
# DP02_121est
# DP02_121pct
# DP02_122est
# DP02_122pct
# DP02_123est
# DP02_123pct
# DP02_124est
# DP02_125est
# DP02_125pct
# DP02_126est
# DP02_126pct
# DP02_127est
# DP02_127pct
# DP02_128est
# DP02_128pct
# DP02_129est
# DP02_129pct
# DP02_130est
# DP02_130pct
# DP02_131est
# DP02_131pct
# DP02_132est
# DP02_132pct
# DP02_133est
# DP02_133pct
# DP02_134est
# DP02_134pct
# DP02_135est
# DP02_135pct
# DP02_136est
# DP02_136pct
# DP02_137est
# DP02_137pct
# DP02_138est
# DP02_138pct
# DP02_139est
# DP02_139pct
# DP02_140est
# DP02_140pct
# DP02_141est
# DP02_141pct
# DP02_142est
# DP02_142pct
# DP02_143est
# DP02_143pct
# DP02_144est
# DP02_144pct
# DP02_145est
# DP02_145pct
# DP02_146est
# DP02_146pct
# DP02_147est
# DP02_147pct
# DP02_148est
# DP02_148pct
# DP02_149est
# DP02_149pct
# DP02_150est
# DP02_150pct
# DP02_151est
# DP02_151pct
# DP02_152est
# DP02_153est
# DP02_153pct
# DP02_154est
# DP02_154pct
# DP03_1est
# DP03_2est
# DP03_2pct
# DP03_3est
# DP03_3pct
# DP03_4est
# DP03_4pct
# DP03_5est
# DP03_5pct
# DP03_6est
# DP03_6pct
# DP03_7est
# DP03_7pct
# DP03_8est
# DP03_9pct
# DP03_10est
# DP03_11est
# DP03_11pct
# DP03_12est
# DP03_12pct
# DP03_13est
# DP03_13pct
# DP03_14est
# DP03_15est
# DP03_15pct
# DP03_16est
# DP03_17est
# DP03_17pct
# DP03_18est
# DP03_19est
# DP03_19pct
# DP03_20est
# DP03_20pct
# DP03_21est
# DP03_21pct
# DP03_22est
# DP03_22pct
# DP03_23est
# DP03_23pct
# DP03_24est
# DP03_24pct
# DP03_25est
# DP03_26est
# DP03_27est
# DP03_27pct
# DP03_28est
# DP03_28pct
# DP03_29est
# DP03_29pct
# DP03_30est
# DP03_30pct
# DP03_31est
# DP03_31pct
# DP03_32est
# DP03_33est
# DP03_33pct
# DP03_34est
# DP03_34pct
# DP03_35est
# DP03_35pct
# DP03_36est
# DP03_36pct
# DP03_37est
# DP03_37pct
# DP03_38est
# DP03_38pct
# DP03_39est
# DP03_39pct
# DP03_40est
# DP03_40pct
# DP03_41est
# DP03_41pct
# DP03_42est
# DP03_42pct
# DP03_43est
# DP03_43pct
# DP03_44est
# DP03_44pct
# DP03_45est
# DP03_45pct
# DP03_46est
# DP03_47est
# DP03_47pct
# DP03_48est
# DP03_48pct
# DP03_49est
# DP03_49pct
# DP03_50est
# DP03_50pct
# DP03_51est
# DP03_52est
# DP03_52pct
# DP03_53est
# DP03_53pct
# DP03_54est
# DP03_54pct
# DP03_55est
# DP03_55pct
# DP03_56est
# DP03_56pct
# DP03_57est
# DP03_57pct
# DP03_58est
# DP03_58pct
# DP03_59est
# DP03_59pct
# DP03_60est
# DP03_60pct
# DP03_61est
# DP03_61pct
# DP03_62est
# DP03_63est
# DP03_64est
# DP03_64pct
# DP03_65est
# DP03_66est
# DP03_66pct
# DP03_67est
# DP03_68est
# DP03_68pct
# DP03_69est
# DP03_70est
# DP03_70pct
# DP03_71est
# DP03_72est
# DP03_72pct
# DP03_73est
# DP03_74est
# DP03_74pct
# DP03_75est
# DP03_76est
# DP03_76pct
# DP03_77est
# DP03_77pct
# DP03_78est
# DP03_78pct
# DP03_79est
# DP03_79pct
# DP03_80est
# DP03_80pct
# DP03_81est
# DP03_81pct
# DP03_82est
# DP03_82pct
# DP03_83est
# DP03_83pct
# DP03_84est
# DP03_84pct
# DP03_85est
# DP03_85pct
# DP03_86est
# DP03_87est
# DP03_88est
# DP03_89est
# DP03_90est
# DP03_91est
# DP03_92est
# DP03_93est
# DP03_94est
# DP03_95est
# DP03_96est
# DP03_96pct
# DP03_97est
# DP03_97pct
# DP03_98est
# DP03_98pct
# DP03_99est
# DP03_99pct
# DP03_100est
# DP03_101est
# DP03_101pct
# DP03_102est
# DP03_103est
# DP03_104est
# DP03_105est
# DP03_105pct
# DP03_106est
# DP03_106pct
# DP03_107est
# DP03_107pct
# DP03_108est
# DP03_108pct
# DP03_109est
# DP03_110est
# DP03_110pct
# DP03_111est
# DP03_111pct
# DP03_112est
# DP03_112pct
# DP03_113est
# DP03_113pct
# DP03_114est
# DP03_115est
# DP03_115pct
# DP03_116est
# DP03_116pct
# DP03_117est
# DP03_117pct
# DP03_118est
# DP03_118pct
# DP03_119pct
# DP03_120pct
# DP03_121pct
# DP03_122pct
# DP03_123pct
# DP03_124pct
# DP03_125pct
# DP03_126pct
# DP03_127pct
# DP03_128pct
# DP03_129pct
# DP03_130pct
# DP03_131pct
# DP03_132pct
# DP03_133pct
# DP03_134pct
# DP03_135pct
# DP03_136pct
# DP03_137pct
# DP05_1est
# DP05_2est
# DP05_2pct
# DP05_3est
# DP05_3pct
# DP05_4est
# DP05_5est
# DP05_5pct
# DP05_6est
# DP05_6pct
# DP05_7est
# DP05_7pct
# DP05_8est
# DP05_8pct
# DP05_9est
# DP05_9pct
# DP05_10est
# DP05_10pct
# DP05_11est
# DP05_11pct
# DP05_12est
# DP05_12pct
# DP05_13est
# DP05_13pct
# DP05_14est
# DP05_14pct
# DP05_15est
# DP05_15pct
# DP05_16est
# DP05_16pct
# DP05_17est
# DP05_17pct
# DP05_18est
# DP05_19est
# DP05_19pct
# DP05_20est
# DP05_20pct
# DP05_21est
# DP05_21pct
# DP05_22est
# DP05_22pct
# DP05_23est
# DP05_23pct
# DP05_24est
# DP05_24pct
# DP05_25est
# DP05_26est
# DP05_26pct
# DP05_27est
# DP05_27pct
# DP05_28est
# DP05_29est
# DP05_30est
# DP05_30pct
# DP05_31est
# DP05_31pct
# DP05_32est
# DP05_33est
# DP05_34est
# DP05_34pct
# DP05_35est
# DP05_35pct
# DP05_36est
# DP05_36pct
# DP05_37est
# DP05_37pct
# DP05_38est
# DP05_38pct
# DP05_39est
# DP05_39pct
# DP05_40est
# DP05_40pct
# DP05_41est
# DP05_41pct
# DP05_42est
# DP05_42pct
# DP05_43est
# DP05_43pct
# DP05_44est
# DP05_44pct
# DP05_45est
# DP05_45pct
# DP05_46est
# DP05_46pct
# DP05_47est
# DP05_47pct
# DP05_48est
# DP05_48pct
# DP05_49est
# DP05_49pct
# DP05_50est
# DP05_50pct
# DP05_51est
# DP05_51pct
# DP05_52est
# DP05_52pct
# DP05_53est
# DP05_53pct
# DP05_54est
# DP05_54pct
# DP05_55est
# DP05_55pct
# DP05_56est
# DP05_56pct
# DP05_57est
# DP05_57pct
# DP05_58est
# DP05_58pct
# DP05_59est
# DP05_59pct
# DP05_60est
# DP05_60pct
# DP05_61est
# DP05_61pct
# DP05_62est
# DP05_62pct
# DP05_63est
# DP05_63pct
# DP05_64est
# DP05_64pct
# DP05_65est
# DP05_66est
# DP05_66pct
# DP05_67est
# DP05_67pct
# DP05_68est
# DP05_68pct
# DP05_69est
# DP05_69pct
# DP05_70est
# DP05_70pct
# DP05_71est
# DP05_71pct
# DP05_72est
# DP05_73est
# DP05_73pct
# DP05_74est
# DP05_74pct
# DP05_75est
# DP05_75pct
# DP05_76est
# DP05_76pct
# DP05_77est
# DP05_77pct
# DP05_78est
# DP05_78pct
# DP05_79est
# DP05_79pct
# DP05_80est
# DP05_80pct
# DP05_81est
# DP05_81pct
# DP05_82est
# DP05_82pct
# DP05_83est
# DP05_83pct
# DP05_84est
# DP05_84pct
# DP05_85est
# DP05_85pct
# DP05_86est
# DP05_86pct
# DP05_87est
# DP05_87pct
# DP05_88est
# DP05_89est
# DP05_90est
# DP05_90pct
# DP05_91est
# DP05_91pct
# PDP02_1est
# PDP02_2est
# PDP02_2pct
# PDP02_3est
# PDP02_3pct
# PDP02_4est
# PDP02_4pct
# PDP02_5est
# PDP02_5pct
# PDP02_6est
# PDP02_7est
# PDP02_7pct
# PDP02_8est
# PDP02_8pct
# PDP02_9est
# PDP02_9pct
# PDP02_10est
# PDP02_10pct
# PDP02_11est
# PDP02_11pct
# PDP02_12est
# PDP02_13est
# PDP02_13pct
# PDP02_14est
# PDP02_14pct
# PDP02_15est
# PDP02_15pct
# PDP02_16est
# PDP02_16pct
# PDP02_17est
# PDP02_17pct
# PDP02_18est
# PDP02_19est
# PDP02_19pct
# PDP02_20est
# PDP02_21est
# PDP02_22est
# PDP02_23est
# PDP02_24est
# PDP02_25est
# PDP02_26est
# PDP02_26pct
# PDP02_27est
# PDP02_27pct
# PDP02_28est
# PDP02_28pct
# PDP02_29est
# PDP02_30est
# PDP02_30pct
# PDP02_31est
# PDP02_31pct
# PDP02_32est
# PDP02_32pct
# PDP02_33est
# PDP02_33pct
# PDP02_34est
# PDP02_34pct
# PDP02_35est
# PDP02_35pct
# PDP02_36est
# PDP02_36pct
# PDP02_37est
# PDP02_37pct
# PDP02_38est
# PDP02_38pct
# PDP02_39est
# PDP02_40est
# PDP02_40pct
# PDP02_41est
# PDP02_42est
# PDP02_42pct
# PDP02_43est
# PDP02_44est
# PDP02_44pct
# PDP02_45est
# PDP02_46est
# PDP02_46pct
# PDP02_47est
# PDP02_48est
# PDP02_48pct
# PDP02_49est
# PDP02_50est
# PDP02_50pct
# PDP02_51est
# PDP02_51pct
# PDP02_52est
# PDP02_52pct
# PDP02_53est
# PDP02_53pct
# PDP02_54est
# PDP02_54pct
# PDP02_55est
# PDP02_55pct
# PDP02_56est
# PDP02_56pct
# PDP02_57est
# PDP02_57pct
# PDP02_58est
# PDP02_59est
# PDP02_59pct
# PDP02_60est
# PDP02_60pct
# PDP02_61est
# PDP02_61pct
# PDP02_62est
# PDP02_62pct
# PDP02_63est
# PDP02_63pct
# PDP02_64est
# PDP02_64pct
# PDP02_65est
# PDP02_66est
# PDP02_66pct
# PDP02_67est
# PDP02_67pct
# PDP02_68est
# PDP02_69est
# PDP02_70est
# PDP02_70pct
# PDP02_71est
# PDP02_71pct
# PDP02_72est
# PDP02_73est
# PDP02_73pct
# PDP02_74est
# PDP02_74pct
# PDP02_75est
# PDP02_76est
# PDP02_76pct
# PDP02_77est
# PDP02_77pct
# PDP02_78est
# PDP02_78pct
# PDP02_79est
# PDP02_79pct
# PDP02_80est
# PDP02_80pct
# PDP02_81est
# PDP02_81pct
# PDP02_82est
# PDP02_83est
# PDP02_83pct
# PDP02_84est
# PDP02_84pct
# PDP02_85est
# PDP02_85pct
# PDP02_86est
# PDP02_86pct
# PDP02_87est
# PDP02_87pct
# PDP02_88est
# PDP02_88pct
# PDP02_89est
# PDP02_89pct
# PDP02_90est
# PDP02_90pct
# PDP02_91est
# PDP02_91pct
# PDP02_92est
# PDP02_92pct
# PDP02_93est
# PDP02_93pct
# PDP02_94est
# PDP02_95est
# PDP02_95pct
# PDP02_96est
# PDP02_96pct
# PDP02_97est
# PDP02_97pct
# PDP02_98est
# PDP02_98pct
# PDP02_99est
# PDP02_99pct
# PDP02_100est
# PDP02_100pct
# PDP02_101est
# PDP02_101pct
# PDP02_102est
# PDP02_102pct
# PDP02_103est
# PDP02_103pct
# PDP02_104est
# PDP02_104pct
# PDP02_105est
# PDP02_105pct
# PDP02_106est
# PDP02_106pct
# PDP02_107est
# PDP02_107pct
# PDP02_108est
# PDP02_108pct
# PDP02_109est
# PDP02_109pct
# PDP02_110est
# PDP02_110pct
# PDP02_111est
# PDP02_111pct
# PDP02_112est
# PDP02_112pct
# PDP02_113est
# PDP02_113pct
# PDP02_114est
# PDP02_114pct
# PDP02_115est
# PDP02_115pct
# PDP02_116est
# PDP02_116pct
# PDP02_117est
# PDP02_117pct
# PDP02_118est
# PDP02_118pct
# PDP02_119est
# PDP02_119pct
# PDP02_120est
# PDP02_120pct
# PDP03_1est
# PDP03_2est
# PDP03_2pct
# PDP03_3est
# PDP03_3pct
# PDP03_4est
# PDP03_4pct
# PDP03_5est
# PDP03_5pct
# PDP03_6est
# PDP03_6pct
# PDP03_7est
# PDP03_7pct
# PDP03_8est
# PDP03_9pct
# PDP03_10est
# PDP03_11est
# PDP03_11pct
# PDP03_12est
# PDP03_12pct
# PDP03_13est
# PDP03_13pct
# PDP03_14est
# PDP03_15est
# PDP03_15pct
# PDP03_16est
# PDP03_16pct
# PDP03_17est
# PDP03_17pct
# PDP03_18est
# PDP03_18pct
# PDP03_19est
# PDP03_19pct
# PDP03_20est
# PDP03_20pct
# PDP03_21est
# PDP03_22est
# PDP03_23est
# PDP03_23pct
# PDP03_24est
# PDP03_24pct
# PDP03_25est
# PDP03_25pct
# PDP03_26est
# PDP03_26pct
# PDP03_27est
# PDP03_27pct
# PDP03_28est
# PDP03_29est
# PDP03_29pct
# PDP03_30est
# PDP03_30pct
# PDP03_31est
# PDP03_31pct
# PDP03_32est
# PDP03_32pct
# PDP03_33est
# PDP03_33pct
# PDP03_34est
# PDP03_34pct
# PDP03_35est
# PDP03_35pct
# PDP03_36est
# PDP03_36pct
# PDP03_37est
# PDP03_37pct
# PDP03_38est
# PDP03_38pct
# PDP03_39est
# PDP03_39pct
# PDP03_40est
# PDP03_40pct
# PDP03_41est
# PDP03_41pct
# PDP03_42est
# PDP03_43est
# PDP03_43pct
# PDP03_44est
# PDP03_44pct
# PDP03_45est
# PDP03_45pct
# PDP03_46est
# PDP03_46pct
# PDP03_47est
# PDP03_48est
# PDP03_49est
# PDP03_50est
# PDP03_51est
# PDP03_51pct
# PDP03_52est
# PDP03_52pct
# PDP03_53est
# PDP03_53pct
# PDP03_54est
# PDP03_54pct
# PDP03_55est
# PDP03_56est
# PDP03_57est
# PDP03_58est
# PDP03_58pct
# PDP03_59est
# PDP03_59pct
# PDP03_60est
# PDP03_60pct
# PDP03_61est
# PDP03_61pct
# PDP03_62est
# PDP03_63est
# PDP03_63pct
# PDP03_64est
# PDP03_64pct
# PDP03_65est
# PDP03_65pct
# PDP03_66est
# PDP03_66pct
# PDP03_67est
# PDP03_68est
# PDP03_68pct
# PDP03_69est
# PDP03_69pct
# PDP03_70est
# PDP03_70pct
# PDP03_71est
# PDP03_71pct
# PDP03_72pct
# PDP03_73pct
# PDP03_74pct
# PDP03_75pct
# PDP05_1est
# PDP05_2est
# PDP05_2pct
# PDP05_3est
# PDP05_3pct
# PDP05_4est
# PDP05_4pct
# PDP05_5est
# PDP05_5pct
# PDP05_6est
# PDP05_6pct
# PDP05_7est
# PDP05_7pct
# PDP05_8est
# PDP05_8pct
# PDP05_9est
# PDP05_9pct
# PDP05_10est
# PDP05_10pct
# PDP05_11est
# PDP05_11pct
# PDP05_12est
# PDP05_13est
# PDP05_13pct
# PDP05_14est
# PDP05_14pct
# PDP05_15est
# PDP05_15pct
# PDP05_16est
# PDP05_17est
# PDP05_17pct
# PDP05_18est
# PDP05_18pct
# PDP05_19est
# PDP05_20est
# PDP05_20pct
# PDP05_21est
# PDP05_21pct
# PDP05_22est
# PDP05_22pct
# PDP05_23est
# PDP05_23pct
# PDP05_24est
# PDP05_24pct
# PDP05_25est
# PDP05_25pct
# PDP05_26est
# PDP05_26pct
# PDP05_27est
# PDP05_27pct
# PDP05_28est
# PDP05_28pct
# PDP05_29est
# PDP05_29pct
# PDP05_30est
# PDP05_30pct
# PDP05_31est
# PDP05_31pct
# PDP05_32est
# PDP05_32pct
# PDP05_33est
# PDP05_33pct
# PDP05_34est
# PDP05_34pct
# PDP05_35est
# PDP05_35pct
# PDP05_36est
# PDP05_36pct
# PDP05_37est
# PDP05_37pct
# PDP05_38est
# PDP05_38pct
# PDP05_39est
# PDP05_39pct
# PDP05_40est
# PDP05_40pct
# PDP05_41est
# PDP05_41pct
# PDP05_42est
# PDP05_42pct
# PDP05_43est
# PDP05_43pct
# PDP05_44est
# PDP05_44pct
# PDP05_45est
# PDP05_45pct
# PDP05_46est
# PDP05_46pct
# PDP05_47est
# PDP05_47pct
# PDP05_48est
# PDP05_48pct
# PDP05_49est
# PDP05_49pct
# PDP05_50est
# PDP05_50pct
# PDP05_51est
# PDP05_52est
# PDP05_52pct
# PDP05_53est
# PDP05_53pct
# PDP05_54est
# PDP05_54pct
# PDP05_55est
# PDP05_55pct
# PDP05_56est
# PDP05_56pct
# PDP05_57est
# PDP05_57pct
# PDP05_58est
# PDP05_59est
# PDP05_59pct
# PDP05_60est
# PDP05_60pct
# PDP05_61est
# PDP05_61pct
# PDP05_62est
# PDP05_62pct
# PDP05_63est
# PDP05_63pct
# PDP05_64est
# PDP05_64pct
# PDP05_65est
# PDP05_65pct
# PDP05_66est
# PDP05_66pct
# PDP05_67est
# PDP05_67pct
# PDP05_68est
# PDP05_68pct
# PDP05_69est
# PDP05_69pct
# PDP05_70est
# PDP05_70pct
# PDP05_71est
# PDP05_71pct
# TCDP02_1est
# TCDP02_2est
# TCDP02_2pct
# TCDP02_3est
# TCDP02_3pct
# TCDP02_4est
# TCDP02_4pct
# TCDP02_5est
# TCDP02_5pct
# TCDP02_6est
# TCDP02_6pct
# TCDP02_7est
# TCDP02_7pct
# TCDP02_8est
# TCDP02_9est
# TCDP02_10est
# TCDP02_11est
# TCDP02_11pct
# TCDP02_12est
# TCDP02_12pct
# TCDP02_13est
# TCDP02_13pct
# TCDP02_14est
# TCDP02_14pct
# TCDP02_15est
# TCDP02_15pct
# TCDP02_16est
# TCDP02_17est
# TCDP02_17pct
# TCDP02_18est
# TCDP02_19est
# TCDP02_19pct
# TCDP02_20est
# TCDP02_21est
# TCDP02_21pct
# TCDP02_22est
# TCDP02_22pct
# TCDP02_23est
# TCDP02_23pct
# TCDP02_24est
# TCDP02_24pct
# TCDP02_25est
# TCDP02_25pct
# TCDP02_26est
# TCDP02_26pct
# TCDP02_27est
# TCDP02_27pct
# TCDP02_28est
# TCDP02_28pct
# TCDP02_29est
# TCDP02_30est
# TCDP02_30pct
# TCDP02_31est
# TCDP02_31pct
# TCDP02_32est
# TCDP02_32pct
# TCDP02_33est
# TCDP02_33pct
# TCDP02_34est
# TCDP02_34pct
# TCDP02_35est
# TCDP02_35pct
# TCDP02_36est
# TCDP02_37est
# TCDP02_37pct
# TCDP02_38est
# TCDP02_38pct
# TCDP02_39est
# TCDP02_40est
# TCDP02_41est
# TCDP02_41pct
# TCDP02_42est
# TCDP02_42pct
# TCDP02_43est
# TCDP02_44est
# TCDP02_44pct
# TCDP02_45est
# TCDP02_45pct
# TCDP02_46est
# TCDP02_47est
# TCDP02_47pct
# TCDP02_48est
# TCDP02_48pct
# TCDP02_49est
# TCDP02_49pct
# TCDP02_50est
# TCDP02_50pct
# TCDP02_51est
# TCDP02_51pct
# TCDP02_52est
# TCDP02_52pct
# TCDP02_53est
# TCDP02_54est
# TCDP02_54pct
# TCDP02_55est
# TCDP02_55pct
# TCDP02_56est
# TCDP02_56pct
# TCDP02_57est
# TCDP02_57pct
# TCDP02_58est
# TCDP02_58pct
# TCDP02_59est
# TCDP02_59pct
# TCDP02_60est
# TCDP02_60pct
# TCDP02_61est
# TCDP02_61pct
# TCDP02_62est
# TCDP02_62pct
# TCDP02_63est
# TCDP02_63pct
# TCDP02_64est
# TCDP02_64pct
# TCDP02_65est
# TCDP02_66est
# TCDP02_66pct
# TCDP02_67est
# TCDP02_67pct
# TCDP02_68est
# TCDP02_68pct
# TCDP02_69est
# TCDP02_69pct
# TCDP02_70est
# TCDP02_70pct
# TCDP02_71est
# TCDP02_71pct
# TCDP02_72est
# TCDP02_72pct
# TCDP02_73est
# TCDP02_73pct
# TCDP02_74est
# TCDP02_74pct
# TCDP02_75est
# TCDP02_75pct
# TCDP02_76est
# TCDP02_76pct
# TCDP02_77est
# TCDP02_77pct
# TCDP02_78est
# TCDP02_78pct
# TCDP02_79est
# TCDP02_79pct
# TCDP02_80est
# TCDP02_80pct
# TCDP02_81est
# TCDP02_81pct
# TCDP02_82est
# TCDP02_82pct
# TCDP02_83est
# TCDP02_83pct
# TCDP02_84est
# TCDP02_84pct
# TCDP02_85est
# TCDP02_85pct
# TCDP02_86est
# TCDP02_86pct
# TCDP02_87est
# TCDP02_87pct
# TCDP02_88est
# TCDP02_88pct
# TCDP02_89est
# TCDP02_89pct
# TCDP02_90est
# TCDP02_90pct
# TCDP02_91est
# TCDP02_91pct
# TCDP02_92est
# TCDP02_92pct
# TCDP02_93est
# TCDP02_94est
# TCDP02_94pct
# TCDP02_95est
# TCDP02_95pct
# TCDP03_1est
# TCDP03_2est
# TCDP03_2pct
# TCDP03_3est
# TCDP03_4est
# TCDP03_4pct
# TCDP03_5est
# TCDP03_6est
# TCDP03_6pct
# TCDP03_7est
# TCDP03_7pct
# TCDP03_8est
# TCDP03_8pct
# TCDP03_9est
# TCDP03_9pct
# TCDP03_10est
# TCDP03_10pct
# TCDP03_11est
# TCDP03_11pct
# TCDP03_12est
# TCDP03_12pct
# TCDP03_13est
# TCDP03_13pct
# TCDP03_14est
# TCDP03_14pct
# TCDP03_15est
# TCDP03_15pct
# TCDP03_16est
# TCDP03_17est
# TCDP03_18est
# TCDP03_19est
# TCDP03_20est
# TCDP03_21est
# TCDP03_22est
# TCDP03_23est
# TCDP03_23pct
# TCDP03_24est
# TCDP03_25est
# TCDP03_25pct
# TCDP03_26est
# TCDP03_27est
# TCDP03_27pct
# TCDP03_28est
# TCDP03_29est
# TCDP03_29pct
# TCDP03_30est
# TCDP03_31est
# TCDP03_31pct
# TCDP03_32est
# TCDP03_33est
# TCDP03_33pct
# TCDP03_34est
# TCDP03_35est
# TCDP03_35pct
# TCDP03_36est
# TCDP03_36pct
# TCDP03_37est
# TCDP03_37pct
# TCDP03_38est
# TCDP03_38pct
# TCDP03_39est
# TCDP03_39pct
# TCDP03_40est
# TCDP03_40pct
# TCDP03_41est
# TCDP03_41pct
# TCDP03_42est
# TCDP03_42pct
# TCDP03_43est
# TCDP03_43pct
# TCDP03_44est
# TCDP03_44pct
# TCDP03_45est
# TCDP03_46est
# TCDP03_47est
# TCDP03_48est
# TCDP03_48pct
# TCDP03_49est
# TCDP03_49pct
# TCDP03_50est
# TCDP03_50pct
# TCDP03_51est
# TCDP03_51pct
# TCDP03_52est
# TCDP03_53est
# TCDP03_53pct
# TCDP03_54pct
# TCDP03_55pct
# TCDP03_56pct
# TCDP03_57pct
# TCDP03_58pct
# TCDP03_59pct
# TCDP03_60pct
# TCDP03_61pct
# TCDP03_62pct
# TCDP03_63pct
# TCDP03_64pct
# TCDP03_65pct
# TCDP03_66pct
# TCDP03_67pct
# TCDP03_68pct
# TCDP05_1est
# TCDP05_2est
# TCDP05_2pct
# TCDP05_3est
# TCDP05_3pct
# TCDP05_4est
# TCDP05_4pct
# TCDP05_5est
# TCDP05_5pct
# TCDP05_6est
# TCDP05_6pct
# TCDP05_7est
# TCDP05_7pct
# TCDP05_8est
# TCDP05_8pct
# TCDP05_9est
# TCDP05_9pct
# TCDP05_10est
# TCDP05_10pct
# TCDP05_11est
# TCDP05_11pct
# TCDP05_12est
# TCDP05_12pct
# TCDP05_13est
# TCDP05_13pct
# TCDP05_14est
# TCDP05_15est
# TCDP05_15pct
# TCDP05_16est
# TCDP05_16pct
# TCDP05_17est
# TCDP05_17pct
# TCDP05_18est
# TCDP05_18pct
# TCDP05_19est
# TCDP05_19pct
# TCDP05_20est
# TCDP05_20pct
# TCDP05_21est
# TCDP05_21pct
# TCDP05_22est
# TCDP05_22pct
# TCDP05_23est
# TCDP05_23pct
# TCDP05_24est
# TCDP05_24pct
# TCDP05_25est
# TCDP05_25pct
# TCDP05_26est
# TCDP05_26pct
# TCDP05_27est
# TCDP05_27pct
# TCDP05_28est
# TCDP05_28pct
# TCDP05_29est
# TCDP05_29pct
# TCDP05_30est
# TCDP05_30pct
# TCDP05_31est
# TCDP05_31pct
# TCDP05_32est
# TCDP05_32pct
# TCDP05_33est
# TCDP05_33pct
# TCDP05_34est
# TCDP05_34pct
# TCDP05_35est
# TCDP05_35pct
# TCDP05_36est
# TCDP05_36pct
# TCDP05_37est
# TCDP05_37pct
# TCDP05_38est
# TCDP05_38pct
# TCDP05_39est
# TCDP05_39pct
# TCDP05_40est
# TCDP05_40pct
# TCDP05_41est
# TCDP05_41pct
# TCDP05_42est
# TCDP05_42pct
# TCDP05_43est
# TCDP05_43pct
# TCDP05_44est
# TCDP05_44pct
# TCDP05_45est
# TCDP05_45pct
# TCDP05_46est
# TCDP05_47est
# TCDP05_47pct
# TCDP05_48est
# TCDP05_48pct
# TCDP05_49est
# TCDP05_49pct
# TCDP05_50est
# TCDP05_50pct
# TCDP05_51est
# TCDP05_51pct
# TCDP05_52est
# TCDP05_52pct
# TCDP05_53est
# TCDP05_54est
# TCDP05_54pct
# TCDP05_55est
# TCDP05_55pct
# TCDP05_56est
# TCDP05_56pct
# TCDP05_57est
# TCDP05_57pct
# TCDP05_58est
# TCDP05_58pct
# TCDP05_59est
# TCDP05_59pct
# TCDP05_60est
# TCDP05_60pct
# TCDP05_61est
# TCDP05_61pct
# TCDP05_62est
# TCDP05_62pct
# TCDP05_63est
# TCDP05_63pct
# TCDP05_64est
# TCDP05_64pct
# TCDP05_65est
# TCDP05_65pct
# TCDP05_66est
# TCDP05_66pct
# TCDP05_67est
# TCDP05_67pct
# TCDP05_68est
# TCDP05_68pct
# TPDP02_1est
# TPDP02_2est
# TPDP02_2pct
# TPDP02_3est
# TPDP02_3pct
# TPDP02_4est
# TPDP02_4pct
# TPDP02_5est
# TPDP02_5pct
# TPDP02_6est
# TPDP02_7est
# TPDP02_7pct
# TPDP02_8est
# TPDP02_8pct
# TPDP02_9est
# TPDP02_9pct
# TPDP02_10est
# TPDP02_10pct
# TPDP02_11est
# TPDP02_11pct
# TPDP02_12est
# TPDP02_13est
# TPDP02_13pct
# TPDP02_14est
# TPDP02_14pct
# TPDP02_15est
# TPDP02_15pct
# TPDP02_16est
# TPDP02_16pct
# TPDP02_17est
# TPDP02_17pct
# TPDP02_18est
# TPDP02_19est
# TPDP02_19pct
# TPDP02_20est
# TPDP02_21est
# TPDP02_22est
# TPDP02_23est
# TPDP02_24est
# TPDP02_25est
# TPDP02_26est
# TPDP02_26pct
# TPDP02_27est
# TPDP02_27pct
# TPDP02_28est
# TPDP02_28pct
# TPDP02_29est
# TPDP02_30est
# TPDP02_30pct
# TPDP02_31est
# TPDP02_31pct
# TPDP02_32est
# TPDP02_32pct
# TPDP02_33est
# TPDP02_33pct
# TPDP02_34est
# TPDP02_34pct
# TPDP02_35est
# TPDP02_35pct
# TPDP02_36est
# TPDP02_36pct
# TPDP02_37est
# TPDP02_37pct
# TPDP02_38est
# TPDP02_38pct
# TPDP02_39est
# TPDP02_40est
# TPDP02_40pct
# TPDP02_41est
# TPDP02_42est
# TPDP02_42pct
# TPDP02_43est
# TPDP02_44est
# TPDP02_44pct
# TPDP02_45est
# TPDP02_46est
# TPDP02_46pct
# TPDP02_47est
# TPDP02_48est
# TPDP02_48pct
# TPDP02_49est
# TPDP02_50est
# TPDP02_50pct
# TPDP02_51est
# TPDP02_51pct
# TPDP02_52est
# TPDP02_52pct
# TPDP02_53est
# TPDP02_53pct
# TPDP02_54est
# TPDP02_54pct
# TPDP02_55est
# TPDP02_55pct
# TPDP02_56est
# TPDP02_56pct
# TPDP02_57est
# TPDP02_57pct
# TPDP02_58est
# TPDP02_59est
# TPDP02_59pct
# TPDP02_60est
# TPDP02_60pct
# TPDP02_61est
# TPDP02_61pct
# TPDP02_62est
# TPDP02_62pct
# TPDP02_63est
# TPDP02_63pct
# TPDP02_64est
# TPDP02_64pct
# TPDP02_65est
# TPDP02_66est
# TPDP02_66pct
# TPDP02_67est
# TPDP02_67pct
# TPDP02_68est
# TPDP02_69est
# TPDP02_70est
# TPDP02_70pct
# TPDP02_71est
# TPDP02_71pct
# TPDP02_72est
# TPDP02_73est
# TPDP02_73pct
# TPDP02_74est
# TPDP02_74pct
# TPDP02_75est
# TPDP02_76est
# TPDP02_76pct
# TPDP02_77est
# TPDP02_77pct
# TPDP02_78est
# TPDP02_78pct
# TPDP02_79est
# TPDP02_79pct
# TPDP02_80est
# TPDP02_80pct
# TPDP02_81est
# TPDP02_81pct
# TPDP02_82est
# TPDP02_83est
# TPDP02_83pct
# TPDP02_84est
# TPDP02_84pct
# TPDP02_85est
# TPDP02_85pct
# TPDP02_86est
# TPDP02_86pct
# TPDP02_87est
# TPDP02_87pct
# TPDP02_88est
# TPDP02_88pct
# TPDP02_89est
# TPDP02_89pct
# TPDP02_90est
# TPDP02_90pct
# TPDP02_91est
# TPDP02_91pct
# TPDP02_92est
# TPDP02_92pct
# TPDP02_93est
# TPDP02_93pct
# TPDP02_94est
# TPDP02_95est
# TPDP02_95pct
# TPDP02_96est
# TPDP02_96pct
# TPDP02_97est
# TPDP02_97pct
# TPDP02_98est
# TPDP02_98pct
# TPDP02_99est
# TPDP02_99pct
# TPDP02_100est
# TPDP02_100pct
# TPDP02_101est
# TPDP02_101pct
# TPDP02_102est
# TPDP02_102pct
# TPDP02_103est
# TPDP02_103pct
# TPDP02_104est
# TPDP02_104pct
# TPDP02_105est
# TPDP02_105pct
# TPDP02_106est
# TPDP02_106pct
# TPDP02_107est
# TPDP02_107pct
# TPDP02_108est
# TPDP02_108pct
# TPDP02_109est
# TPDP02_109pct
# TPDP02_110est
# TPDP02_110pct
# TPDP02_111est
# TPDP02_111pct
# TPDP02_112est
# TPDP02_112pct
# TPDP02_113est
# TPDP02_113pct
# TPDP02_114est
# TPDP02_114pct
# TPDP02_115est
# TPDP02_115pct
# TPDP02_116est
# TPDP02_116pct
# TPDP02_117est
# TPDP02_117pct
# TPDP02_118est
# TPDP02_118pct
# TPDP02_119est
# TPDP02_119pct
# TPDP02_120est
# TPDP02_120pct
# TPDP03_1est
# TPDP03_2est
# TPDP03_2pct
# TPDP03_3est
# TPDP03_3pct
# TPDP03_4est
# TPDP03_4pct
# TPDP03_5est
# TPDP03_5pct
# TPDP03_6est
# TPDP03_6pct
# TPDP03_7est
# TPDP03_7pct
# TPDP03_8est
# TPDP03_9pct
# TPDP03_10est
# TPDP03_11est
# TPDP03_11pct
# TPDP03_12est
# TPDP03_12pct
# TPDP03_13est
# TPDP03_13pct
# TPDP03_14est
# TPDP03_15est
# TPDP03_15pct
# TPDP03_16est
# TPDP03_16pct
# TPDP03_17est
# TPDP03_17pct
# TPDP03_18est
# TPDP03_18pct
# TPDP03_19est
# TPDP03_19pct
# TPDP03_20est
# TPDP03_20pct
# TPDP03_21est
# TPDP03_22est
# TPDP03_23est
# TPDP03_23pct
# TPDP03_24est
# TPDP03_24pct
# TPDP03_25est
# TPDP03_25pct
# TPDP03_26est
# TPDP03_26pct
# TPDP03_27est
# TPDP03_27pct
# TPDP03_28est
# TPDP03_29est
# TPDP03_29pct
# TPDP03_30est
# TPDP03_30pct
# TPDP03_31est
# TPDP03_31pct
# TPDP03_32est
# TPDP03_32pct
# TPDP03_33est
# TPDP03_33pct
# TPDP03_34est
# TPDP03_34pct
# TPDP03_35est
# TPDP03_35pct
# TPDP03_36est
# TPDP03_36pct
# TPDP03_37est
# TPDP03_37pct
# TPDP03_38est
# TPDP03_38pct
# TPDP03_39est
# TPDP03_39pct
# TPDP03_40est
# TPDP03_40pct
# TPDP03_41est
# TPDP03_41pct
# TPDP03_42est
# TPDP03_43est
# TPDP03_43pct
# TPDP03_44est
# TPDP03_44pct
# TPDP03_45est
# TPDP03_45pct
# TPDP03_46est
# TPDP03_46pct
# TPDP03_47est
# TPDP03_48est
# TPDP03_49est
# TPDP03_50est
# TPDP03_51est
# TPDP03_51pct
# TPDP03_52est
# TPDP03_52pct
# TPDP03_53est
# TPDP03_53pct
# TPDP03_54est
# TPDP03_54pct
# TPDP03_55est
# TPDP03_56est
# TPDP03_57est
# TPDP03_58est
# TPDP03_58pct
# TPDP03_59est
# TPDP03_59pct
# TPDP03_60est
# TPDP03_60pct
# TPDP03_61est
# TPDP03_61pct
# TPDP03_62est
# TPDP03_63est
# TPDP03_63pct
# TPDP03_64est
# TPDP03_64pct
# TPDP03_65est
# TPDP03_65pct
# TPDP03_66est
# TPDP03_66pct
# TPDP03_67est
# TPDP03_68est
# TPDP03_68pct
# TPDP03_69est
# TPDP03_69pct
# TPDP03_70est
# TPDP03_70pct
# TPDP03_71est
# TPDP03_71pct
# TPDP03_72pct
# TPDP03_73pct
# TPDP03_74pct
# TPDP03_75pct
# TPDP05_1est
# TPDP05_2est
# TPDP05_2pct
# TPDP05_3est
# TPDP05_3pct
# TPDP05_4est
# TPDP05_4pct
# TPDP05_5est
# TPDP05_5pct
# TPDP05_6est
# TPDP05_6pct
# TPDP05_7est
# TPDP05_7pct
# TPDP05_8est
# TPDP05_8pct
# TPDP05_9est
# TPDP05_9pct
# TPDP05_10est
# TPDP05_10pct
# TPDP05_11est
# TPDP05_11pct
# TPDP05_12est
# TPDP05_13est
# TPDP05_13pct
# TPDP05_14est
# TPDP05_14pct
# TPDP05_15est
# TPDP05_15pct
# TPDP05_16est
# TPDP05_17est
# TPDP05_17pct
# TPDP05_18est
# TPDP05_18pct
# TPDP05_19est
# TPDP05_20est
# TPDP05_20pct
# TPDP05_21est
# TPDP05_21pct
# TPDP05_22est
# TPDP05_22pct
# TPDP05_23est
# TPDP05_23pct
# TPDP05_24est
# TPDP05_24pct
# TPDP05_25est
# TPDP05_25pct
# TPDP05_26est
# TPDP05_26pct
# TPDP05_27est
# TPDP05_27pct
# TPDP05_28est
# TPDP05_28pct
# TPDP05_29est
# TPDP05_29pct
# TPDP05_30est
# TPDP05_30pct
# TPDP05_31est
# TPDP05_31pct
# TPDP05_32est
# TPDP05_32pct
# TPDP05_33est
# TPDP05_33pct
# TPDP05_34est
# TPDP05_34pct
# TPDP05_35est
# TPDP05_35pct
# TPDP05_36est
# TPDP05_36pct
# TPDP05_37est
# TPDP05_37pct
# TPDP05_38est
# TPDP05_38pct
# TPDP05_39est
# TPDP05_39pct
# TPDP05_40est
# TPDP05_40pct
# TPDP05_41est
# TPDP05_41pct
# TPDP05_42est
# TPDP05_42pct
# TPDP05_43est
# TPDP05_43pct
# TPDP05_44est
# TPDP05_44pct
# TPDP05_45est
# TPDP05_45pct
# TPDP05_46est
# TPDP05_46pct
# TPDP05_47est
# TPDP05_47pct
# TPDP05_48est
# TPDP05_48pct
# TPDP05_49est
# TPDP05_49pct
# TPDP05_50est
# TPDP05_50pct
# TPDP05_51est
# TPDP05_52est
# TPDP05_52pct
# TPDP05_53est
# TPDP05_53pct
# TPDP05_54est
# TPDP05_54pct
# TPDP05_55est
# TPDP05_55pct
# TPDP05_56est
# TPDP05_56pct
# TPDP05_57est
# TPDP05_57pct
# TPDP05_58est
# TPDP05_59est
# TPDP05_59pct
# TPDP05_60est
# TPDP05_60pct
# TPDP05_61est
# TPDP05_61pct
# TPDP05_62est
# TPDP05_62pct
# TPDP05_63est
# TPDP05_63pct
# TPDP05_64est
# TPDP05_64pct
# TPDP05_65est
# TPDP05_65pct
# TPDP05_66est
# TPDP05_66pct
# TPDP05_67est
# TPDP05_67pct
# TPDP05_68est
# TPDP05_68pct
# TPDP05_69est
# TPDP05_69pct
# TPDP05_70est
# TPDP05_70pct
# TPDP05_71est
# TPDP05_71pct

# %%
# Merging all 15 files into 1 with only selected columns (estimates and percentage)

import os
import pandas as pd

# Get the current working directory (where the script is located)
current_dir = os.path.abspath("")

# Initialize an empty DataFrame to store the combined data
demographic_main_data = pd.DataFrame(columns=unique_column_names)

# Initialize counters for tracking changes
total_columns_filled = 0
total_rows_added = 0

# Set to keep track of unique columns filled across all files
columns_filled_set = set()

# Iterate over each folder in the current directory
for item_name in os.listdir(current_dir):
    item_path = os.path.join(current_dir, item_name)
    
    if os.path.isdir(item_path):
        # Construct the expected Excel file path
        excel_file_path = os.path.join(item_path, f"{item_name}.xlsx")
        
        # Check if the Excel file exists
        if os.path.exists(excel_file_path):
            print(f"Processing Excel file: {item_name}")
            
            # Read the data from the Excel file
            df = pd.read_excel(excel_file_path)
            
            # Filter columns based on unique_column_names
            df_filtered = df[[col for col in df.columns if col in unique_column_names]]

            # Merge the filtered data frame into the main demographic data frame
            demographic_main_data = pd.merge(
                demographic_main_data,
                df_filtered,
                on=['GeoId', 'Geography', 'LEAID', 'Year'],
                how='outer',
                suffixes=('', '_new')
            )

            # Update the columns filled with new data
            for col in df_filtered.columns:
                if col not in ['GeoId', 'Geography', 'LEAID', 'Year']:
                    # If the original column contains NaN, fill it with the new data
                    demographic_main_data[col].fillna(demographic_main_data[f'{col}_new'], inplace=True)
                    # Drop the new column
                    demographic_main_data.drop(columns=[f'{col}_new'], inplace=True)
                    # Add to the set of filled columns
                    columns_filled_set.add(col)

            # Log changes after processing the data frame
            num_rows_after = len(demographic_main_data)
            num_new_rows = num_rows_after - total_rows_added
            total_rows_added += num_new_rows
#             total_columns_filled += len(df_filtered.columns) - 4  # Exclude LEAID, Geography, GeoId, Year
            print(f"    Rows added: {num_new_rows}")
            print(f"    Columns filled with data: {len(columns_filled_set)}")
            print(f"    Total rows in combined data: {num_rows_after}")
            print(f"    Total columns in combined data: {len(demographic_main_data.columns)}\n")

            
# Save the combined DataFrame to a new Excel file
output_file_path = os.path.abspath('Demographic_main_data.xlsx')
demographic_main_data.to_excel(output_file_path, index=False)

print(f"\nData from all Excel files has been combined and saved to: {output_file_path}")
print(f"Total rows: {total_rows_added}")
print(f"Total columns: {len(demographic_main_data.columns)}")
# Out:
# Processing Excel file: Parent of Relevant Children Demographic 2018-2022
#     Rows added: 10683
#     Columns filled with data: 136
#     Total rows in combined data: 10683
#     Total columns in combined data: 2442
#
# Processing Excel file: Parent of Relevant Children Economic 2018-2022
#     Rows added: 0
#     Columns filled with data: 264
#     Total rows in combined data: 10683
#     Total columns in combined data: 2442
#
# Processing Excel file: Parent of Relevant Children Social 2018-2022
#     Rows added: 0
#     Columns filled with data: 479
#     Total rows in combined data: 10683
#     Total columns in combined data: 2442
#
# Processing Excel file: Relevant Children Demographic 2018-2022
#     Rows added: 705
#     Columns filled with data: 611
#     Total rows in combined data: 11388
#     Total columns in combined data: 2442
#
# Processing Excel file: Relevant Children Economic 2018-2022
#     Rows added: 0
#     Columns filled with data: 712
#     Total rows in combined data: 11388
#     Total columns in combined data: 2442
#
# Processing Excel file: Relevant Children Social 2018-2022
#     Rows added: 0
#     Columns filled with data: 886
#     Total rows in combined data: 11388
#     Total columns in combined data: 2442
#
# Processing Excel file: Total Children Demographic 2018-2022
#     Rows added: 0
#     Columns filled with data: 1018
#     Total rows in combined data: 11388
#     Total columns in combined data: 2442
#
# Processing Excel file: Total Children Economic 2018-2022
#     Rows added: 0
#     Columns filled with data: 1119
#     Total rows in combined data: 11388
#     Total columns in combined data: 2442
#
# Processing Excel file: Total Children Social 2018-2022
#     Rows added: 0
#     Columns filled with data: 1293
#     Total rows in combined data: 11388
#     Total columns in combined data: 2442
#
# Processing Excel file: Total Parents Demographic 2018-2022
#     Rows added: 0
#     Columns filled with data: 1429
#     Total rows in combined data: 11388
#     Total columns in combined data: 2442
#
# Processing Excel file: Total Parents Economic 2018-2022
#     Rows added: 0
#     Columns filled with data: 1557
#     Total rows in combined data: 11388
#     Total columns in combined data: 2442
#
# Processing Excel file: Total Parents Social 2018-2022
#     Rows added: 0
#     Columns filled with data: 1772
#     Total rows in combined data: 11388
#     Total columns in combined data: 2442
#
# Processing Excel file: Total Population Demographic 2018-2022
#     Rows added: 2011
#     Columns filled with data: 1942
#     Total rows in combined data: 13399
#     Total columns in combined data: 2442
#
# Processing Excel file: Total Population Economic 2018-2022
#     Rows added: 0
#     Columns filled with data: 2161
#     Total rows in combined data: 13399
#     Total columns in combined data: 2442
#
# Processing Excel file: Total Population Social 2018-2022
#     Rows added: 0
#     Columns filled with data: 2438
#     Total rows in combined data: 13399
#     Total columns in combined data: 2442
#
#
# Data from all Excel files has been combined and saved to: C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Demographic_main_data.xlsx
# Total rows: 13399
# Total columns: 2442

# %%
# Reorder the columns to ensure always_included_columns are first
ordered_columns = always_included_columns + [col for col in demographic_main_data.columns if col not in always_included_columns]
demographic_main_data = demographic_main_data[ordered_columns]

# Save the combined DataFrame to a new Excel file
output_file_path = os.path.abspath('Demographic_main_data.xlsx')
demographic_main_data.to_excel(output_file_path, index=False)

print(f"\nData from all Excel files has been combined and saved to: {output_file_path}")
print(f"Total rows added: {total_rows_added}")
print(f"Total columns filled with data: {len(demographic_main_data.columns)}")
# Out:
# Data from all Excel files has been combined and saved to: C:\Users\nnngu\OneDrive\Documents\School\Georgia Tech\Summer 2024\K-12 Data Solutions\Data\NCES Data\NCES Demographic data\Demographic_main_data.xlsx
# Total rows added: 13399
# Total columns filled with data: 2442

# %%
# Splitting the main data into 2: one for estimates and one for percentage

# Columns to retain in both datasets
common_columns = ['GeoId', 'Geography', 'LEAID', 'Year']

# Identify columns that end with "est" and "pct"
est_columns = [col for col in demographic_main_data.columns if col.endswith('est')]
pct_columns = [col for col in demographic_main_data.columns if col.endswith('pct')]

# Create datasets
df_est = demographic_main_data[common_columns + est_columns]
df_pct = demographic_main_data[common_columns + pct_columns]

# Save the new datasets to Excel files
df_est.to_excel('Demographic_main_data_est.xlsx', index=False)
df_pct.to_excel('Demographic_main_data_pct.xlsx', index=False)

# Display the new datasets (optional)
print("EST Dataset:\n", df_est.head())
print("PCT Dataset:\n", df_pct.head())
# Out:
# EST Dataset:
#                GeoId                                   Geography   LEAID  \
# 0  9700000US0200007  Aleutians East Borough School District, AK  200007
# 1  9700000US0200180               Anchorage School District, AK  200180
# 2  9700000US0200020           Bering Strait School District, AK  200020
# 3  9700000US0200030     Bristol Bay Borough School District, AK  200030
# 4  9700000US0200070            Copper River School District, AK  200070
#
#         Year  CDP02_1est  CDP02_2est  CDP02_3est  CDP02_4est  CDP02_5est  \
# 0  2018-2022       215.0       100.0        45.0        15.0        55.0
# 1  2018-2022     23970.0     15390.0      2300.0      2030.0      4250.0
# 2  2018-2022       935.0       380.0       205.0       145.0       210.0
# 3  2018-2022        40.0        30.0         4.0         4.0         4.0
# 4  2018-2022       170.0       120.0         4.0        25.0        20.0
#
#    CDP02_6est  ...  TPDP05_62est  TPDP05_63est  TPDP05_64est  TPDP05_65est  \
# 0         0.0  ...           0.0           0.0         370.0          45.0
# 1         0.0  ...         165.0        1455.0       52630.0       32495.0
# 2         0.0  ...           0.0           0.0        1275.0          60.0
# 3         0.0  ...           0.0           0.0         105.0          50.0
# 4         0.0  ...           0.0           0.0         395.0         250.0
#
#    TPDP05_66est  TPDP05_67est  TPDP05_68est  TPDP05_69est  TPDP05_70est  \
# 0           4.0         215.0          60.0           4.0           0.0
# 1        2655.0        3630.0        6700.0        2125.0         325.0
# 2           0.0        1160.0           4.0           0.0           0.0
# 3           0.0          25.0          10.0           0.0           0.0
# 4           0.0         130.0           0.0           0.0           0.0
#
#    TPDP05_71est
# 0          40.0
# 1        4705.0
# 2          50.0
# 3          15.0
# 4          15.0
#
# [5 rows x 1320 columns]
# PCT Dataset:
#                GeoId                                   Geography   LEAID  \
# 0  9700000US0200007  Aleutians East Borough School District, AK  200007
# 1  9700000US0200180               Anchorage School District, AK  200180
# 2  9700000US0200020           Bering Strait School District, AK  200020
# 3  9700000US0200030     Bristol Bay Borough School District, AK  200030
# 4  9700000US0200070            Copper River School District, AK  200070
#
#         Year  CDP02_2pct  CDP02_3pct  CDP02_4pct  CDP02_5pct  CDP02_6pct  \
# 0  2018-2022        46.5        20.9         7.0        25.6         NaN
# 1  2018-2022        64.2         9.6         8.5        17.7         NaN
# 2  2018-2022        40.6        21.9        15.5        22.5         NaN
# 3  2018-2022        75.0        10.0        10.0        10.0         NaN
# 4  2018-2022        70.6         2.4        14.7        11.8         NaN
#
#    CDP02_7pct  ...  TPDP05_62pct  TPDP05_63pct  TPDP05_64pct  TPDP05_65pct  \
# 0         7.0  ...           NaN           NaN          97.4          11.8
# 1         9.2  ...           0.3           2.5          91.4          56.4
# 2        21.9  ...           NaN           NaN          99.6           4.7
# 3        10.0  ...           NaN           NaN          91.3          43.5
# 4         2.4  ...           NaN           NaN          84.9          53.8
#
#    TPDP05_66pct  TPDP05_67pct  TPDP05_68pct  TPDP05_69pct  TPDP05_70pct  \
# 0           1.1          56.6          15.8           1.1           NaN
# 1           4.6           6.3          11.6           3.7           0.6
# 2           NaN          90.6           0.3           NaN           NaN
# 3           NaN          21.7           8.7           NaN           NaN
# 4           NaN          28.0           NaN           NaN           NaN
#
#    TPDP05_71pct
# 0          10.5
# 1           8.2
# 2           3.9
# 3          13.0
# 4           3.2
#
# [5 rows x 1126 columns]
